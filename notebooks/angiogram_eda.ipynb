# %% [markdown]
# # Coronary Angiogram Dataset Exploration
#
# This notebook demonstrates dataset inspection, preprocessing, and qualitative visualisation steps for the coronary artery segmentation project.
#
# ## Suggested Steps
#
# 1. **Environment setup**
#    - Activate the project virtual environment and ensure dependencies from `requirements.txt` are installed.
#
# 2. **Load dataset pairs**
#    - Use functions from `src.preprocessing` to enumerate image/mask paths.
#    - Compute dataset statistics with `describe_dataset`.
#
# 3. **Visual checks**
#    - Sample a handful of angiograms and overlay their masks using `visualize_samples`.
#
# 4. **Augmentation sanity checks**
#    - Apply `default_augmentation_pipeline` from `src.data.dataset` to view transformed samples.
#
# 5. **Model-ready tensors**
#    - Instantiate `AngiogramSegmentationDataset` and inspect tensor shapes/values to verify normalisation.
#
# Use this notebook as an entry point for additional experiments, such as building custom augmentations or integrating the Segment Anything Model (SAM) for zero-shot trials.
